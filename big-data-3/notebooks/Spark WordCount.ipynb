# %%
lines = sc.textFile("hdfs:/user/cloudera/words.txt")

# %%
lines.count()
# Out:
# 124456

# %%
lines.take(3)
# Out:
# ['This is the 100th Etext file presented by Project Gutenberg, and',
#  'is presented in cooperation with World Library, Inc., from their',
#  'Library of the Future and Shakespeare CDROMS.  Project Gutenberg']

# %%
words = lines.flatMap(lambda line : line.split(" "))

# %%
tuples = words.map(lambda word : (word, 1))

# %%
tuples.take(3)
# Out:
# [('This', 1), ('is', 1), ('the', 1)]

# %%
counts = tuples.reduceByKey(lambda a, b: (a + b))

# %%
counts.coalesce(1).saveAsTextFile('hdfs:/user/cloudera/wordcount/outputDir3')

# %%
counts.collect()
# Out:
# [('', 517065),
#  ('Quince', 1),
#  ('Corin,', 2),
#  ('Just', 10),
#  ('enrooted', 1),
#  ('divers', 20),
#  ('Doubtless', 2),
#  ('undistinguishable,', 1),
#  ('widowhood,', 1),
#  ('incorporate.', 1),
#  ('rare,', 10),
#  ('Sir-I', 1),
#  ("Stain'd", 2),
#  ('Mopsa,', 1),
#  ("O'erpays", 1),
#  ('a-going?', 1),
#  ('perfection.', 5),
#  ('twice,', 2),
#  ('LIBRARY,', 221),
#  ('Gloucestershire;', 3),
#  ('escape,', 2),
#  ('ftp', 2),
#  ('outright.', 2),
#  ("Majesty's.", 1),
#  ('whole?', 1),
#  ('heir-apparent', 1),
#  ('exposture', 1),
#  ('melt.', 3),
#  ('falseness', 1),
#  ('Fo,', 2),
#  ('why', 183),
#  ("tribunes'", 1),
#  ('ladybird!', 1),
#  ('circle', 10),
#  ('preceding', 3),
#  ('inhabitants!', 1),
#  ("o'erreaches;", 1),
#  ('Chi', 1),
#  ('untimely', 15),
#  ('suppresseth', 1),
#  ('adultress.', 2),
#  ('mutiny', 10),
#  ('Fidele', 1),
#  ('unavoided', 4),
#  ('car]', 1),
#  ('scaped', 1),
#  ('combine,', 1),
#  ('depositaries;', 1),
#  ("table's", 1),
#  ('True!', 2),
#  ('tales.', 3),
#  ('humility.', 4),
#  ('mart', 9),
#  ('errors', 8),
#  ('Abbey,', 1),
#  ('countermand', 2),
#  ('Buy', 4),
#  ('talents', 4),
#  ('Suffer', 4),
#  ('dread', 40),
#  ('Unfix', 1),
#  ('Albany?', 2),
#  ('attorney.', 1),
#  ('ACT_4|SC_1', 2),
#  ('Milan!', 1),
#  ('award', 1),
#  ('clay?', 1),
#  ('Bohemian-Tartar', 1),
#  ('inscription', 1),
#  ('kiss,', 10),
#  ("Brandish'd", 1),
#  ('payment.', 3),
#  ('Perdita!', 1),
#  ('stalk', 5),
#  ('bawd!', 3),
#  ('dines', 2),
#  ("will?'", 1),
#  ('supper.', 11),
#  ('forecast,', 1),
#  ('seek?', 1),
#  ('praise;', 5),
#  ('fulsome!', 1),
#  ('straining', 2),
#  ('Vile', 2),
#  ('masks', 2),
#  ('explication;', 1),
#  ('Levy', 1),
#  ("'t!", 5),
#  ('neighing', 4),
#  ("kitten'd,", 1),
#  ('Claudio;', 6),
#  ('plea', 5),
#  ('tradition,', 1),
#  ('velure,', 1),
#  ("lover's", 11),
#  ('addrest.', 1),
#  ('millstones', 1),
#  ('machine', 2),
#  ('disposing', 4),
#  ('held:', 1),
#  ("pois'd", 2),
#  ('ghost', 12),
#  ('Tranio?', 1),
#  ('Possible.', 1),
#  ('neglecting', 2),
#  ('assaileth', 1),
#  ('agnize', 1),
#  ('DOLL]', 1),
#  ('Roses', 2),
#  ('Interpretation', 2),
#  ('Ephesus', 6),
#  ('Hamlet.]', 2),
#  ('Stoop,', 3),
#  ('befriended', 1),
#  ('looks', 132),
#  ('"This', 2),
#  ("Accomplish'd", 1),
#  ('IX.', 6),
#  ('strangers.', 1),
#  ('heard', 289),
#  ('ducdame;', 1),
#  ('sailing', 2),
#  ('lawful.', 4),
#  ("ladies'", 11),
#  ('smock,', 1),
#  ('leaning', 4),
#  ('exercise,', 3),
#  ('handkerchief.', 4),
#  ('unfortunate;', 1),
#  ('jack-', 1),
#  ('Amen;', 1),
#  ('helter-skelter', 1),
#  ('attendant', 14),
#  ('damns', 1),
#  ("threaten'd", 3),
#  ('thing)', 1),
#  ('ideas,', 1),
#  ('talons?', 1),
#  ('honesty', 46),
#  ('warm,', 3),
#  ('alteration', 5),
#  ('who-', 3),
#  ('musicians', 7),
#  ('VENICE.', 18),
#  ('Remember,', 9),
#  ("hard-favour'd", 2),
#  ('shepherdes', 1),
#  ('impotence', 1),
#  ('sons!', 4),
#  ('unfortunate.', 1),
#  ('coronation;', 2),
#  ('garboils,', 1),
#  ('cozeners!-', 1),
#  ('ear;', 10),
#  ("dismay'd:", 1),
#  ('remembrancer', 1),
#  ('Muse,', 5),
#  ('lethargied-', 1),
#  ('queen.', 38),
#  ('million.', 3),
#  ('blunt,', 4),
#  ('bigamy.', 1),
#  ('Repugnant', 1),
#  ('overboard,', 1),
#  ('smocks,', 1),
#  ("slough,'", 1),
#  ('requested.', 1),
#  ('bones', 37),
#  ("whosoe'er", 1),
#  ('Mount,', 3),
#  ('obey', 41),
#  ('raw', 8),
#  ('birthplace', 1),
#  ("friendship.'", 1),
#  ('here:', 2),
#  ("slobb'ry", 1),
#  ('footboys.', 1),
#  ('equipage.', 1),
#  ('bastinado', 1),
#  ('Nerissa?', 1),
#  ('prejudice;', 1),
#  ('Pandars.', 1),
#  ('Popilius', 2),
#  ('Desdemona', 26),
#  ("med'cine", 4),
#  ('turtle,', 3),
#  ('Unnatural', 2),
#  ('If!', 1),
#  ('lady', 174),
#  ("'choose'!", 1),
#  ('continent', 9),
#  ('Shakes', 4),
#  ("men's;", 2),
#  ('over-blown,', 1),
#  ('Cornwall.', 3),
#  ('statesman', 1),
#  ('Edgar!', 1),
#  ('captivate.', 1),
#  ('vanity.', 3),
#  ('expect?', 1),
#  ('also,', 7),
#  ("cuckoo'-", 2),
#  ('pander!', 1),
#  ('visited;', 2),
#  ('MACDUFF,', 2),
#  ('declines;', 1),
#  ('Honour,', 4),
#  ('likely,', 2),
#  ('suspicion?', 4),
#  ('Suggested', 1),
#  ('shame,', 68),
#  ('bulls.', 1),
#  ('stray', 5),
#  ("worst.'", 1),
#  ('courtesies', 5),
#  ('turned,', 1),
#  ("up,'", 1),
#  ('stew:', 1),
#  ('so;', 123),
#  ('Mome,', 1),
#  ('coasts?', 1),
#  ('straw?', 2),
#  ('Curtis!', 1),
#  ("help'd", 4),
#  ('leasing;', 1),
#  ('best-moving', 1),
#  ('Add', 5),
#  ('leve,', 1),
#  ('forehand', 3),
#  ('ISABELLA,', 1),
#  ('proposition', 1),
#  ("court.'", 2),
#  ('Dishonestly', 1),
#  ('slumbers.', 1),
#  ("pawn'd", 7),
#  ('Saving', 4),
#  ('sea-sick,', 1),
#  ('furniture', 3),
#  ('sleepy,', 1),
#  ('sounding', 2),
#  ('FORD]', 2),
#  ('speech;', 5),
#  ('depending,', 2),
#  ('Falconbridge', 1),
#  ('frets', 3),
#  ('William:', 1),
#  ('negatives', 1),
#  ('argued', 1),
#  ('Excite', 1),
#  ("'Ho!'", 1),
#  ("waken'd", 2),
#  ('Dismount', 1),
#  ('speciously', 2),
#  ('yield,', 12),
#  ('a-feasting;', 1),
#  ("island's", 1),
#  ('proceedings.', 5),
#  ('field-bed', 1),
#  ('SCROOP.', 12),
#  ('cashier;', 1),
#  ('organ.', 1),
#  ('understandeth', 1),
#  ('cold!', 1),
#  ('mistful', 1),
#  ('backbite.', 1),
#  ('disgorge', 3),
#  ("off'rings", 1),
#  ('fly-bitten', 1),
#  ("there's", 175),
#  ('ipse', 1),
#  ('waist,', 4),
#  ('events!', 1),
#  ("marr'd.", 3),
#  ('tree]', 1),
#  ('waist', 8),
#  ('Gorgon,', 1),
#  ('languageless,', 1),
#  ('alligator', 1),
#  ("Hear'st", 4),
#  ("play's", 1),
#  ("'fore", 2),
#  ('aboard,', 6),
#  ('take,', 15),
#  ('pregnantly', 1),
#  ('father-', 12),
#  ('us?', 46),
#  ('ships?', 2),
#  ('merest', 1),
#  ('vice;', 3),
#  ('Porter', 1),
#  ('Lucentio!', 1),
#  ('Because-', 1),
#  ('gorge', 3),
#  ("'Henry", 1),
#  ('Quickly;', 2),
#  ('ALIENA,', 1),
#  ('disclaimers', 2),
#  ('Art', 79),
#  ('Jack', 38),
#  ('Patroclus', 8),
#  ('galling', 1),
#  ('Abbey', 5),
#  ('BELARIUS,', 9),
#  ('Information', 2),
#  ('reword;', 1),
#  ('War,', 1),
#  ('sails!', 1),
#  ('debonair,', 1),
#  ('offended.', 8),
#  ('Chatham.', 1),
#  ("outlaw'd", 1),
#  ("sick-fall'n", 1),
#  ('harbourage', 1),
#  ('puppies,', 1),
#  ('thereof;', 5),
#  ('Imitari', 1),
#  ('brows.', 6),
#  ('foot-licker.', 1),
#  ('flood.', 3),
#  ('character),', 1),
#  ('tattling.', 1),
#  ('heart-offending', 1),
#  ('maidenhead!', 1),
#  ("list.'", 1),
#  ('Climb', 1),
#  ('Benvolio.', 3),
#  ('favours-', 1),
#  ('gibbet', 2),
#  ('Kikely,', 1),
#  ('poli,', 1),
#  ('beginners!-', 1),
#  ('[Pushes', 2),
#  ('Europe!', 1),
#  ('Lodowick,', 1),
#  ('baiting-place.', 1),
#  ('rough,', 11),
#  ('Guards,', 3),
#  ('create,', 1),
#  ('sold;', 2),
#  ('walk,', 8),
#  ('Mightiness', 1),
#  ('loses.', 1),
#  ('Caliban!', 1),
#  ('expediently,', 1),
#  ('Cor.', 31),
#  ('privacy,', 1),
#  ('plumes', 1),
#  ('rightfully', 1),
#  ('Gives', 16),
#  ('waste:', 1),
#  ('upon', 1337),
#  ('Score', 1),
#  ('Fitzwater,', 3),
#  ('altogether', 20),
#  ('HUBERT.', 52),
#  ('discase', 2),
#  ('disability;', 1),
#  ('example,', 5),
#  ('Headborough.', 1),
#  ('damage', 3),
#  ('utter', 30),
#  ('Commentaries', 1),
#  ('Bunch', 1),
#  ('homage:', 1),
#  ('leave-taking.', 1),
#  ('tomb', 19),
#  ("so-forth.'", 1),
#  ('rampant', 1),
#  ('litter', 6),
#  ('Daughter),', 1),
#  ('ginger-bread.', 1),
#  ('parley', 15),
#  ('ALEXANDER.', 8),
#  ('creation.', 1),
#  ('intended;', 1),
#  ('wildness;', 2),
#  ('wager,', 4),
#  ('posture.', 1),
#  ('use', 257),
#  ('sense?', 3),
#  ('indifferently.', 1),
#  ('superfluity,', 1),
#  ('hinc.', 1),
#  ('stronger;', 1),
#  ('example.', 5),
#  ("pow'r;", 1),
#  ('brainsick', 3),
#  ('bents', 1),
#  ('graves.', 7),
#  ('delays;', 1),
#  ('coronets)', 1),
#  ('owed,', 1),
#  ('catching', 5),
#  ('her', 2822),
#  ('blind-worms,', 1),
#  ('bed-rite', 1),
#  ("cank'red", 5),
#  ('Confusion', 2),
#  ('Paphos,', 1),
#  ('kites.', 1),
#  ('O-', 6),
#  ('burden.', 6),
#  ('deputy', 14),
#  ("fork'd", 2),
#  ('Hungarian', 1),
#  ('in;', 45),
#  ('Englishmen', 2),
#  ('Elizabeth,', 2),
#  ('butchery,', 2),
#  ('trials', 3),
#  ('withering', 2),
#  ('captain,', 15),
#  ('fitter', 8),
#  ('midnight.', 5),
#  ('lingers', 4),
#  ('quality;', 3),
#  ('ward;', 2),
#  ('oxen,', 3),
#  ('indulgent.', 1),
#  ('sirrah;', 6),
#  ('idleness.', 5),
#  ("subscrib'd.", 1),
#  ("Nerissa's", 1),
#  ('yourselves', 33),
#  ('[Awaking]', 3),
#  ('Quarrelsome;', 1),
#  ('distribute,', 1),
#  ('Comprising', 1),
#  ('ESCALUS.', 79),
#  ('Upbraided', 1),
#  ('wantons', 2),
#  ('owns', 1),
#  ('cloister?', 1),
#  ("untrain'd", 1),
#  ('cords,', 3),
#  ('Warwick,', 68),
#  ("den.'", 1),
#  ('close', 61),
#  ("appeas'd", 2),
#  ("dagger's", 2),
#  ('satisfied!', 8),
#  ('halcyon', 2),
#  ('justly;', 2),
#  ('brimstone!', 2),
#  ('Elbow?', 1),
#  ('away-the', 1),
#  ('ensnare', 1),
#  ('curse:', 1),
#  ('confidence.', 3),
#  ('knives,', 2),
#  ('cakes', 3),
#  ('over-roasted', 1),
#  ('scope,', 4),
#  ('amount.', 2),
#  ('sun;', 10),
#  ('perpend:', 1),
#  ('Searching', 1),
#  ("sow'd;", 1),
#  ('breeds,', 1),
#  ("burn'd", 4),
#  ('booties', 1),
#  ('derive.', 1),
#  ('helmet', 5),
#  ('above', 96),
#  ('REAPERS,', 1),
#  ('Fiery?', 2),
#  ('frost,', 4),
#  ('Tom?', 1),
#  ('firebrand', 1),
#  ('Walking', 1),
#  ('influences,', 2),
#  ('ship,', 5),
#  ('dust.', 11),
#  ('lower', 13),
#  ('honourably', 2),
#  ('ISABELLA.', 129),
#  ('scambling', 1),
#  ('knavery.', 4),
#  ('avoiding', 1),
#  ("traitor's", 11),
#  ("bestow't", 1),
#  ('astronomical?', 1),
#  ("Lay't", 1),
#  ('chafe.', 1),
#  ('profit', 26),
#  ('poll?', 1),
#  ('brown.', 2),
#  ('lie.', 27),
#  ('badge,', 2),
#  ('walk;', 1),
#  ('cart', 5),
#  ('Volumnius:', 1),
#  ('shortly', 28),
#  ("utt'rance.", 1),
#  ('Coldly', 1),
#  ('whore-master', 1),
#  ('Curse,', 1),
#  ('herb', 5),
#  ('publish', 8),
#  ('foiled,', 1),
#  ('groves', 2),
#  ("weak'ned?", 1),
#  ('Rascal', 1),
#  ('torches,', 1),
#  ('PAULINA,', 6),
#  ('tongue!', 7),
#  ('her!-', 2),
#  ('kernels.', 1),
#  ('Riddles!', 1),
#  ('resembled', 3),
#  ('Frederick,', 3),
#  ('vault', 9),
#  ('Brags', 1),
#  ('Cardinal-', 1),
#  ('Keeps', 7),
#  ('waking,', 7),
#  ('took.', 4),
#  ('semblance-', 1),
#  ('humbled,', 1),
#  ('terribly', 1),
#  ('overcome,', 1),
#  ('laugh', 64),
#  ('homeward', 3),
#  ("cousin'-", 1),
#  ('mountain-top', 2),
#  ('supper?', 6),
#  ('parties,', 4),
#  ('princess;', 2),
#  ("smil'd,", 1),
#  ('sinfully', 1),
#  ('invention,', 9),
#  ('inflammation.', 1),
#  ('sorcerers,', 1),
#  ('horses', 31),
#  ('quality.', 11),
#  ('ill', 157),
#  ("fire's", 2),
#  ('tartness', 1),
#  ('foregone,', 2),
#  ("nimble-pinion'd", 1),
#  ('oppress', 2),
#  ('Hide', 5),
#  ('degraded,', 1),
#  ('three-hours', 1),
#  ('ETEXT', 223),
#  ('he,', 122),
#  ('beliest', 1),
#  ('coins', 2),
#  ('early;', 2),
#  ('softly;', 2),
#  ('espy', 2),
#  ('ESCALUS]', 1),
#  ('reels.', 1),
#  ('chin!', 1),
#  ('furthest', 2),
#  ('Somerset', 27),
#  ('beat,', 4),
#  ('seduced?', 1),
#  ('rescued', 3),
#  ('betters.', 1),
#  ('wilt.', 14),
#  ('afar]', 1),
#  ('tally,', 1),
#  ('hag,', 3),
#  ('camping', 1),
#  ('roof,', 1),
#  ("Lysander's", 3),
#  ('apparent,', 3),
#  ('DOLABELLA,', 3),
#  ("survey'd", 1),
#  ('compound:', 1),
#  ('afoot:', 1),
#  ('Softer', 1),
#  ('Sher.', 5),
#  ('ELIZABETH.', 102),
#  ('Southwark?', 1),
#  ('baldrick,', 1),
#  ('Alarum,', 4),
#  ('epitaph;', 1),
#  ('feet,', 13),
#  ("'Whip", 1),
#  ('much.', 56),
#  ('fear;', 23),
#  ('coz?', 3),
#  ('Office,', 1),
#  ('ELY,', 2),
#  ('savages-', 1),
#  ('abbess', 1),
#  ('elevated', 1),
#  ('avoid?', 1),
#  ("up.'", 2),
#  ('rags?-', 1),
#  ('pipe.', 1),
#  ('give!', 1),
#  ("Sprawl'st", 1),
#  ('Perseverance,', 1),
#  ('Bootless', 3),
#  ('anatomy', 2),
#  ('wolvish-ravening', 1),
#  ('rules', 6),
#  ('outrage;', 1),
#  ('oxlips,', 1),
#  ('world?', 13),
#  ('examine.', 2),
#  ('soothe', 4),
#  ("year's", 3),
#  ('sand-blind,', 1),
#  ("'Will',", 2),
#  ("foemen's", 1),
#  ('instant', 45),
#  ('horror?', 1),
#  ('malignancy', 1),
#  ('perpetuity', 2),
#  ('profound;', 1),
#  ("Falstaff's", 7),
#  ('Philippi.', 6),
#  ('searce', 1),
#  ('weep', 82),
#  ('genitivo,', 1),
#  ('salve?', 2),
#  ('fardel?', 1),
#  ('oath?', 9),
#  ('prosper!', 1),
#  ('capite;', 1),
#  ('happiest', 4),
#  ("glory's", 1),
#  ('screech-owl,', 1),
#  ('Fight,', 3),
#  ('Woncot', 1),
#  ("gor'd", 3),
#  ('participate.', 1),
#  ('Exposing', 2),
#  ('glove?', 2),
#  ('remedy?', 6),
#  ('neglect', 17),
#  ('refusest.', 1),
#  ('device?', 2),
#  ('Acquitted', 1),
#  ('LEONTES,', 7),
#  ("scotch'd", 2),
#  ('derision!', 1),
#  ("unmann'd", 2),
#  ('sacrifice,', 5),
#  ('cleave,', 2),
#  ('does!', 2),
#  ('news?', 61),
#  ('Ho,', 12),
#  ('Hero:', 1),
#  ("us'd", 42),
#  ('knight!', 5),
#  ('Francis-', 1),
#  ('weights', 2),
#  ('horrible.', 3),
#  ('soilure,', 1),
#  ("ang'red", 4),
#  ('lunacy?', 1),
#  ('bestraught.', 1),
#  ("aim'd", 4),
#  ("displac'd;", 1),
#  ("sooth'st", 1),
#  ('Faint-hearted', 2),
#  ('walled', 1),
#  ('highest!', 1),
#  ("were't", 7),
#  ('name?', 50),
#  ('cities,', 6),
#  ('consolation-', 1),
#  ('flocks', 3),
#  ('Makes', 44),
#  ('Aves', 1),
#  ('gone!', 21),
#  ('hailstones,', 1),
#  ('hurry,', 1),
#  ('months-', 2),
#  ('hare', 9),
#  ('clothes?', 4),
#  ('Christian-like', 3),
#  ('pulpit.', 3),
#  ('vanquished,', 1),
#  ('dare-', 1),
#  ('rhyme', 11),
#  ('urging', 8),
#  ("'orld:", 1),
#  ("mourn'd", 4),
#  ('wronk:', 1),
#  ('questant', 1),
#  ('143', 1),
#  ('shields', 1),
#  ('unripe,', 1),
#  ('destroy.', 2),
#  ('election,', 3),
#  ('jester.', 2),
#  ('langues', 1),
#  ("'hum,'", 1),
#  ("plast'ring", 1),
#  ('"twas', 1),
#  ('sand;', 1),
#  ('numb.', 1),
#  ("hammer'd", 2),
#  ("England's", 63),
#  ('parlous', 3),
#  ('mercenary.', 2),
#  ('truth!', 5),
#  ('PETO,', 1),
#  ("Embowell'd", 2),
#  ('book-men:', 1),
#  ('conditions;', 5),
#  ('serge,', 1),
#  ('sleep-', 2),
#  ('dowry', 15),
#  ('bishops', 1),
#  ('skittish', 3),
#  ('Bennet', 1),
#  ('justly.', 2),
#  ('furrows', 1),
#  ('SENATOR,', 1),
#  ('it]', 2),
#  ('Adrian.', 1),
#  ('eunuchs', 2),
#  ('wedding-day,', 1),
#  ('neither.', 20),
#  ("arriv'd.", 2),
#  ("Scorn'dst", 1),
#  ('masters!-', 1),
#  ('spectators,', 2),
#  ('allegiance!', 2),
#  ('uphold', 3),
#  ('Proteus,', 30),
#  ('ARIEL', 11),
#  ('aloud;', 2),
#  ('thyself!', 6),
#  ('temperate.', 1),
#  ('rascal!', 12),
#  ('ruled', 4),
#  ('calm,', 5),
#  ('charity!', 1),
#  ('EROS', 6),
#  ('doublets', 2),
#  ('vanity!', 3),
#  ("turn'd,", 4),
#  ('SHALLOW]', 2),
#  ('reverence.', 5),
#  ('lamb;', 3),
#  ('needle;', 2),
#  ("'til", 1),
#  ('troubles;', 2),
#  ('harms,', 3),
#  ('dump-', 1),
#  ('SURVEYOR.', 9),
#  ('Welcome', 21),
#  ('tuners', 1),
#  ('land-thieves-', 1),
#  ('helpful', 4),
#  ('effectual.', 1),
#  ('Lady', 114),
#  ('roundure', 1),
#  ('branches-it', 1),
#  ('QUINCE,', 5),
#  ('accidental', 2),
#  ("'Many", 2),
#  ('Rescue', 2),
#  ("Martem'", 1),
#  ('arrow,', 2),
#  ('rings', 7),
#  ('at;', 10),
#  ("sauc'd", 3),
#  ('secret?', 2),
#  ('contented,', 3),
#  ("o'erhanging", 1),
#  ('celsa', 1),
#  ('scathe', 4),
#  ("rogues'", 1),
#  ('Statue', 1),
#  ("preserv'd,", 1),
#  ('book,', 19),
#  ("lesson'd", 2),
#  ('Fourth,', 5),
#  ("Rome.'", 1),
#  ('tempestuous', 3),
#  ('aediles,', 1),
#  ('Hag-seed,', 1),
#  ('milder?', 1),
#  ('already?', 3),
#  ('apperil,', 1),
#  ('coverlet,', 1),
#  ('combatants', 1),
#  ("cardinal's", 3),
#  ('screeching', 1),
#  ('porters,', 1),
#  ('continues', 2),
#  ('CORIOLANUS', 14),
#  ('Player.]', 1),
#  ('heap-', 1),
#  ("daub'd", 1),
#  ("'Fie", 1),
#  ('germans.', 1),
#  ('wombs', 2),
#  ('dribbling', 1),
#  ('scornfully;', 1),
#  ('hand]', 2),
#  ('wrathful,', 2),
#  ('importunacy', 1),
#  ('quaintly', 4),
#  ('ye?', 4),
#  ('uprightness', 1),
#  ('sheep', 16),
#  ('altered', 2),
#  ('beareth', 1),
#  ('torturing', 2),
#  ("lessen'd;", 1),
#  ('nunnery.', 2),
#  ('Personates', 1),
#  ("ransom'd,", 2),
#  ('ho?', 9),
#  ('swarming', 1),
#  ('shivers', 1),
#  ('cook?', 2),
#  ('exit.', 1),
#  ('lowliness.', 1),
#  ('Courses', 1),
#  ('advisor**', 1),
#  ('arbour.]', 3),
#  ('wide;', 2),
#  ('swoop?', 1),
#  ('satire,', 1),
#  ('widow?', 1),
#  ('UNDER', 2),
#  ('rabblement', 2),
#  ('admits.', 1),
#  ('Doricles', 1),
#  ('crouching', 1),
#  ('Mary.', 1),
#  ('straw,', 5),
#  ('dissolute', 4),
#  ('Goneril]', 8),
#  ('wet', 12),
#  ('Hallowmas,', 1),
#  ('peopled', 2),
#  ('sacrifices.', 1),
#  ('Yorkshire', 5),
#  ('Whereupon', 1),
#  ('damnation.', 3),
#  ('bidding.', 5),
#  ("remember't", 1),
#  ('hair?', 1),
#  ("displeas'd,", 1),
#  ('voutsafe', 1),
#  ('dearer,', 2),
#  ('Frances!', 1),
#  ("mock'ry", 1),
#  ('Bassanio!', 1),
#  ('[beneath]', 3),
#  ("mix'd,", 1),
#  ('gay,', 1),
#  ("mast'red,", 1),
#  ("fear'st.", 1),
#  ('dost.', 2),
#  ('knee,', 22),
#  ('women?', 6),
#  ('wretch,', 24),
#  ('stare,', 5),
#  ('nostril', 2),
#  ('MARTEXT,', 1),
#  ('piety', 2),
#  ('fifteen', 16),
#  ('cabin!', 1),
#  ('Shame', 10),
#  ('commodious', 1),
#  ('widow!', 1),
#  ('sworn', 97),
#  ("'silver", 2),
#  ('keeps,', 2),
#  ('biscuit', 1),
#  ("lott'ry.", 1),
#  ('landed,', 3),
#  ('EVANS', 16),
#  ("bargain'd", 2),
#  ('infinitely', 3),
#  ("o'erwhelm'd", 1),
#  ('scenes,', 1),
#  ('robin', 1),
#  ('prince.', 14),
#  ('hers.', 13),
#  ('departing.', 2),
#  ('blackness', 1),
#  ('Forever,', 1),
#  ('honey', 28),
#  ('default', 3),
#  ('wine-but', 1),
#  ('fas', 1),
#  ('Gloucester:', 1),
#  ('fancies,', 1),
#  ('maintain', 31),
#  ("sped.'", 1),
#  ('Wiped', 1),
#  ('harelip;', 1),
#  ("grows'-", 1),
#  ('firmly.', 1),
#  ('Freedom', 1),
#  ('prince', 49),
#  ('well-paid', 1),
#  ('Arabia', 3),
#  ('wealth;', 1),
#  ('counsels', 11),
#  ('entirely?', 1),
#  ('soon?', 1),
#  ('wallow', 2),
#  ('tombed', 1),
#  ('gentle.', 2),
#  ('amber', 4),
#  ('lawyer-', 1),
#  ('news!', 7),
#  ('rarely,', 1),
#  ("nurse's", 3),
#  ('harmful', 8),
#  ('beaks', 1),
#  ('instructions.', 1),
#  ('sting,', 3),
#  ('curtle-axe', 2),
#  ('diminishing,', 1),
#  ('unrewarded', 1),
#  ('weening', 2),
#  ('hautboys,', 2),
#  ('Wife.', 20),
#  ('gloriously', 1),
#  ('thimble.', 1),
#  ('surer', 2),
#  ('down:', 2),
#  ('flourish,', 5),
#  ('Olivia-', 1),
#  ('Tester', 1),
#  ('L.', 1),
#  ('tawny-coats.', 1),
#  ('prowess', 3),
#  ('Oh,', 3),
#  ('lady!', 37),
#  ('arrived,', 2),
#  ('gown.', 15),
#  ('house:', 2),
#  ('Edward', 92),
#  ('Edgar', 9),
#  ('redemption!', 1),
#  ('weapon', 13),
#  ("did't", 1),
#  ('Yet,', 61),
#  ('bounty.', 3),
#  ('value-', 1),
#  ('following].', 1),
#  ('tarry.', 5),
#  ('affright', 7),
#  ('gul', 1),
#  ('dishes;', 1),
#  ('gown', 17),
#  ('court-hand.', 1),
#  ('tiger', 3),
#  ('melancholy;', 2),
#  ('Fail', 2),
#  ("unarm'd", 2),
#  ("su'd", 1),
#  ("scatter'd;", 1),
#  ('unfathered,', 1),
#  ('enrank', 1),
#  ('portrait', 1),
#  ('sciences', 1),
#  ('LIKE', 1),
#  ("clos'd", 5),
#  ('DUKE]', 4),
#  ('sunburnt', 1),
#  ('mystery;', 4),
#  ('Convinced', 1),
#  ('council:', 1),
#  ('Ilium?', 3),
#  ('deux', 2),
#  ('Pigrogromitus,', 1),
#  ('fecks!', 1),
#  ('prest', 2),
#  ('lunatics?', 1),
#  ('viper', 2),
#  ('babes', 10),
#  ('abominably.', 1),
#  ('crack-hemp.', 1),
#  ('warming-pan.', 1),
#  ("can'st", 1),
#  ('garden,', 5),
#  ('apprehensions', 1),
#  ('elbow;', 1),
#  ("'abbominable.'", 1),
#  ('points;', 2),
#  ('Senate!', 1),
#  ('Body', 1),
#  ('faithfully?', 1),
#  ('yet.', 50),
#  ("govern'd,", 1),
#  ('actual', 2),
#  ('TOPAS]', 1),
#  ('path,', 2),
#  ('lasted,', 1),
#  ('imagine,', 2),
#  ('purity!', 1),
#  ('[CHARMIAN', 1),
#  ...]
